# %%
from modules import df
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
from modules import load_data
load_data()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# 5                    0.41             0.50               2
# 6                    0.10             0.77               6
# 7                    0.92             0.85               5
# 8                    0.89             1.00               5
# 9                    0.42             0.53               2
# 10                   0.45             0.54               2
# 11                   0.11             0.81               6
# 12                   0.84             0.92               4
# 13                   0.41             0.55               2
# 14                   0.36             0.56               2
# ...

# %%
from modules import separate
separate('stayed')
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 2000                 0.58             0.74               4
# 2001                 0.82             0.67               2
# 2002                 0.45             0.69               5
# 2003                 0.78             0.82               5
# 2004                 0.49             0.60               3
# 2005                 0.36             0.95               3
# 2006                 0.54             0.37               2
# 2007                 0.99             0.91               5
# 2008                 0.50             0.75               6
# 2009                 0.74             0.64               4
# 2010                 0.56             0.58               4
# 2011                 0.34             0.39               2
# 2012                 0.48             0.94               5
# 2013                 0.73             0.62               3
# 2014                 0.59             0.87               3
# ...

# %%
from modules import summary_stats
summary_stats()
# Out:
# /home/dsci/capstone/attrition/attrition/modules.py:40: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   return means.sort('difference',ascending=False)[1:]
#                            stayed        left  difference
# time_spend_company       3.380032    3.876505   14.688433
# average_montly_hours   199.060203  207.419210    4.199236
# number_project           3.786664    3.855503    1.817915
# last_evaluation          0.715473    0.718113    0.368871
# satisfaction_level       0.666810    0.440098  -33.999448
# Work_accident            0.175009    0.047326  -72.958107
# promotion_last_5years    0.026251    0.005321  -79.731914

# %%
import matplotlib.pyplot as plt
from modules import corr_plot
# %matplotlib inline
plt.figure(figsize=(10,10))
corr_plot()

# %%
from modules import hist
hist()

# %%
from modules import scatter_matrix1
# %matplotlib inline
scatter_matrix1()

# %%
from pandas.tools.plotting import scatter_matrix

# %%
scatter_matrix?
